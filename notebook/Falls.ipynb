# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Percentage of IRF patients who experience one or more falls with major injury during their IRF stay

# %%
Provider_data_25=pd.read_csv('../data/Inpatient_Rehabilitation_Facility_Provider_Data_Jun2025.csv')

# %%
National_Data_25= pd.read_csv('../data/Inpatient_Rehabilitation_Facility_National_Data_Jun2025.csv')

# %%
Provider_data_24=pd.read_csv('../data/Inpatient_Rehabilitation_Facility-Provider_Data_Jun2024.csv')

# %%
National_Data_24= pd.read_csv('../data/Inpatient_Rehabilitation_Facility-National_Data_Jun2024.csv')

# %%
Provider_data_23=pd.read_csv('../data/Inpatient_Rehabilitation_Facility-Provider_Data_Jun2023.csv')

# %%
National_Data_23=pd.read_csv('../data/Inpatient_Rehabilitation_Facility-National_Data_Jun2023.csv')

# %%
Provider_data_22=pd.read_csv('../data/Inpatient_Rehabilitation_Facility-Provider_Data_Jun2022.csv')

# %%
National_Data_22=pd.read_csv('../data/Inpatient_Rehabilitation_Facility-National_Data_Jun2022.csv')

# %%
Provider_data_20=pd.read_csv('../data/Inpatient Rehabilitation Facility-Provider Data_Jun2020.csv')

# %%
National_Data_20=pd.read_csv('../data/Inpatient Rehabilitation Facility-National Data_Jun2020.csv')

# %%
Falls_25= Provider_data_25.loc[(Provider_data_25['Measure Code']=='I_013_01_OBS_RATE') | (Provider_data_25['Measure Code']=='I_013_01_NUMERATOR') | (Provider_data_25['Measure Code']=='I_013_01_DENOMINATOR')]

# %%
Falls_25
# Out:
#       CMS Certification Number (CCN)  \
# 7                              13025
# 8                              13025
# 9                              13025
# 75                             13028
# 76                             13028
# ...                              ...
# 83172                         743030
# 83173                         743030
# 83239                         743031
# 83240                         743031
# 83241                         743031
#
#                                            Provider Name  \
# 7      ENCOMPASS HEALTH LAKESHORE REHABILITATION HOSP...
# 8      ENCOMPASS HEALTH LAKESHORE REHABILITATION HOSP...
# 9      ENCOMPASS HEALTH LAKESHORE REHABILITATION HOSP...
# 75       ENCOMPASS REHABILITATION HOSPITAL OF MONTGOMERY
# 76       ENCOMPASS REHABILITATION HOSPITAL OF MONTGOMERY
# ...                                                  ...
# 83172  ENCOMPASS HEALTH REHABILITATION OF HOUSTON AT THE
# 83173  ENCOMPASS HEALTH REHABILITATION OF HOUSTON AT THE
# 83239             HORIZON MEDICAL CENTER OF MCKINNEY LLC
# 83240             HORIZON MEDICAL CENTER OF MCKINNEY LLC
# 83241             HORIZON MEDICAL CENTER OF MCKINNEY LLC
#
#                 Address Line 1 Address Line 2   City/Town State  ZIP Code  \
# 7          3800 RIDGEWAY DRIVE              -  BIRMINGHAM    AL     35209
# 8          3800 RIDGEWAY DRIVE              -  BIRMINGHAM    AL     35209
# 9          3800 RIDGEWAY DRIVE              -  BIRMINGHAM    AL     35209
# 75         4465 NARROW LANE RD              -  MONTGOMERY    AL     36116
# 76         4465 NARROW LANE RD              -  MONTGOMERY    AL     36116
# ...                        ...            ...         ...   ...       ...
# 83172    3010 YELLOWSTONE BLVD              -     HOUSTON    TX     77054
# 83173    3010 YELLOWSTONE BLVD              -     HOUSTON    TX     77054
# 83239  6601 W UNIVERSITY DRIVE              -   MC KINNEY    TX     75071
# 83240  6601 W UNIVERSITY DRIVE              -   MC KINNEY    TX     75071
# 83241  6601 W UNIVERSITY DRIVE              -   MC KINNEY    TX     75071
#
#       County/Parish Telephone Number  CMS Region          Measure Code  \
# 7         Jefferson   (205) 868-2000           4  I_013_01_DENOMINATOR
# 8         Jefferson   (205) 868-2000           4    I_013_01_NUMERATOR
# 9         Jefferson   (205) 868-2000           4     I_013_01_OBS_RATE
# 75       Montgomery   (334) 284-7821           4  I_013_01_DENOMINATOR
# 76       Montgomery   (334) 284-7821           4    I_013_01_NUMERATOR
# ...             ...              ...         ...                   ...
# 83172        Harris   (832) 380-7200           6    I_013_01_NUMERATOR
# 83173        Harris   (832) 380-7200           6     I_013_01_OBS_RATE
# 83239        Collin   (469) 907-1355           6  I_013_01_DENOMINATOR
# 83240        Collin   (469) 907-1355           6    I_013_01_NUMERATOR
# 83241        Collin   (469) 907-1355           6     I_013_01_OBS_RATE
#
#                Score Footnote Start Date   End Date Measure Date Range
# 7              1,900        -  10/1/2023  9/30/2024                  -
# 8                  1        -  10/1/2023  9/30/2024                  -
# 9                0.1        -  10/1/2023  9/30/2024                  -
# 75             1,373        -  10/1/2023  9/30/2024                  -
# 76                 5        -  10/1/2023  9/30/2024                  -
# ...              ...      ...        ...        ...                ...
# 83172  Not Available        2  10/1/2023  9/30/2024                  -
# 83173  Not Available        2  10/1/2023  9/30/2024                  -
# 83239  Not Available        2  10/1/2023  9/30/2024                  -
# 83240  Not Available        2  10/1/2023  9/30/2024                  -
# 83241  Not Available        2  10/1/2023  9/30/2024                  -
#
# [3675 rows x 16 columns]

# %%
NC_Falls_25_Rate= Falls_25.loc[(Falls_25['Measure Code']=='I_013_01_OBS_RATE') &(Falls_25['State']=='NC')].drop(columns=['Address Line 1','Address Line 2', 'City/Town','ZIP Code','Telephone Number','Footnote','Start Date','End Date', 'Measure Date Range']).reset_index(drop=True)

# %%
NC_Falls_25_Rate.head(10)
# Out:
#   CMS Certification Number (CCN)                           Provider Name  \
# 0                         343025    CAREPARTNERS REHABILITATION HOSPITAL
# 1                         343026                CAROLINAS REHABILITATION
# 2                         343027   NOVANT HEALTH REHABILITATION HOSPITAL
# 3                         34T004            HIGH POINT REGIONAL HOSPITAL
# 4                         34T008              CENTER FOR INPATIENT REHAB
# 5                         34T014          WHITAKER REHABILITATION CENTER
# 6                         34T015           ROWAN REGIONAL MEDICAL CENTER
# 7                         34T027     LENOIR MEMORIAL HOSPITAL REHAB UNIT
# 8                         34T028  CAPE FEAR VALLEY REHABILITATION CENTER
# 9                         34T040           PITT COUNTY MEMORIAL HOSPITAL
#
#   State County/Parish  CMS Region       Measure Code          Score
# 0    NC      Buncombe           4  I_013_01_OBS_RATE            0.1
# 1    NC   Mecklenburg           4  I_013_01_OBS_RATE            0.1
# 2    NC       Forsyth           4  I_013_01_OBS_RATE            0.4
# 3    NC      Guilford           4  I_013_01_OBS_RATE              0
# 4    NC      Scotland           4  I_013_01_OBS_RATE  Not Available
# 5    NC       Forsyth           4  I_013_01_OBS_RATE  Not Available
# 6    NC         Rowan           4  I_013_01_OBS_RATE              0
# 7    NC        Lenoir           4  I_013_01_OBS_RATE            0.5
# 8    NC    Cumberland           4  I_013_01_OBS_RATE            0.2
# 9    NC          Pitt           4  I_013_01_OBS_RATE            0.4

# %%
NC_Falls_25_Rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 7 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   CMS Certification Number (CCN)  26 non-null     object
#  1   Provider Name                   26 non-null     object
#  2   State                           26 non-null     object
#  3   County/Parish                   26 non-null     object
#  4   CMS Region                      26 non-null     int64
#  5   Measure Code                    26 non-null     object
#  6   Score                           26 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 1.6+ KB

# %%
rows_to_drop= NC_Falls_25_Rate.loc[NC_Falls_25_Rate['Score']=='Not Available']
rows_to_drop
# Out:
#    CMS Certification Number (CCN)                          Provider Name  \
# 4                          34T008             CENTER FOR INPATIENT REHAB
# 5                          34T014         WHITAKER REHABILITATION CENTER
# 15                         34T097  REGIONAL REHAB CENTER AT HUGH CHATHAM
# 17                         34T113               CAROLINAS MEDICAL CENTER
#
#    State County/Parish  CMS Region       Measure Code          Score
# 4     NC      Scotland           4  I_013_01_OBS_RATE  Not Available
# 5     NC       Forsyth           4  I_013_01_OBS_RATE  Not Available
# 15    NC         Surry           4  I_013_01_OBS_RATE  Not Available
# 17    NC   Mecklenburg           4  I_013_01_OBS_RATE  Not Available

# %%
NC_Falls_25_Rate=NC_Falls_25_Rate.drop(rows_to_drop.index, axis=0)
NC_Falls_25_Rate
# Out:
#    CMS Certification Number (CCN)  \
# 0                          343025
# 1                          343026
# 2                          343027
# 3                          34T004
# 6                          34T015
# 7                          34T027
# 8                          34T028
# 9                          34T040
# 10                         34T047
# 11                         34T053
# 12                         34T061
# 13                         34T069
# 14                         34T091
# 16                         34T098
# 18                         34T115
# 19                         34T116
# 20                         34T131
# 21                         34T132
# 22                         34T141
# 23                         34T143
# 24                         34T147
# 25                         34T155
#
#                                         Provider Name State County/Parish  \
# 0                CAREPARTNERS REHABILITATION HOSPITAL    NC      Buncombe
# 1                            CAROLINAS REHABILITATION    NC   Mecklenburg
# 2               NOVANT HEALTH REHABILITATION HOSPITAL    NC       Forsyth
# 3                        HIGH POINT REGIONAL HOSPITAL    NC      Guilford
# 6                       ROWAN REGIONAL MEDICAL CENTER    NC         Rowan
# 7                 LENOIR MEMORIAL HOSPITAL REHAB UNIT    NC        Lenoir
# 8              CAPE FEAR VALLEY REHABILITATION CENTER    NC    Cumberland
# 9                       PITT COUNTY MEMORIAL HOSPITAL    NC          Pitt
# 10                   NORTH CAROLINA BAPTIST HOSPITALS    NC       Forsyth
# 11          NOVANT HEALTH PRESBYTERIAN MEDICAL CENTER    NC   Mecklenburg
# 12                      UNC HOSPITALS INPATIENT REHAB    NC        Orange
# 13                                      WAKEMED REHAB    NC          Wake
# 14                    MOSES H. CONE MEMORIAL HOSPITAL    NC      Guilford
# 16  CAROLINAS MEDICAL CENTER - PINEVILLE REHABILIT...    NC   Mecklenburg
# 18                FIRSTHEALTH MOORE REGIONAL HOSPITAL    NC         Moore
# 19                   DLP FRYE REGIONAL MEDICAL CENTER    NC       Catawba
# 20               CAROLINAEAST REHABILITATION HOSPITAL    NC        Craven
# 21            MARIA PARHAM HEALTHCARE ASSOCIATION INC    NC         Vance
# 22  NEW HANOVER REGIONAL MEDICAL CENTER REHABILITA...    NC   New Hanover
# 23                      CATAWBA VALLEY MEDICAL CENTER    NC       Catawba
# 24           BRYANT T. ALDRIDGE REHABILITATION CENTER    NC          Nash
# 25                           DURHAM REGIONAL HOSPITAL    NC        Durham
#
#     CMS Region       Measure Code Score
# 0            4  I_013_01_OBS_RATE   0.1
# 1            4  I_013_01_OBS_RATE   0.1
# 2            4  I_013_01_OBS_RATE   0.4
# 3            4  I_013_01_OBS_RATE     0
# 6            4  I_013_01_OBS_RATE     0
# 7            4  I_013_01_OBS_RATE   0.5
# 8            4  I_013_01_OBS_RATE   0.2
# 9            4  I_013_01_OBS_RATE   0.4
# 10           4  I_013_01_OBS_RATE   0.3
# 11           4  I_013_01_OBS_RATE     0
# 12           4  I_013_01_OBS_RATE   0.2
# 13           4  I_013_01_OBS_RATE     0
# 14           4  I_013_01_OBS_RATE     0
# 16           4  I_013_01_OBS_RATE   0.4
# 18           4  I_013_01_OBS_RATE   0.5
# 19           4  I_013_01_OBS_RATE     0
# 20           4  I_013_01_OBS_RATE     0
# 21           4  I_013_01_OBS_RATE     0
# 22           4  I_013_01_OBS_RATE   0.2
# 23           4  I_013_01_OBS_RATE     0
# 24           4  I_013_01_OBS_RATE   0.3
# 25           4  I_013_01_OBS_RATE     0

# %%
NC_Falls_25_Rate['Score']=NC_Falls_25_Rate['Score'].astype(str).astype(float)
NC_Falls_25_Rate
# Out:
#    CMS Certification Number (CCN)  \
# 0                          343025
# 1                          343026
# 2                          343027
# 3                          34T004
# 6                          34T015
# 7                          34T027
# 8                          34T028
# 9                          34T040
# 10                         34T047
# 11                         34T053
# 12                         34T061
# 13                         34T069
# 14                         34T091
# 16                         34T098
# 18                         34T115
# 19                         34T116
# 20                         34T131
# 21                         34T132
# 22                         34T141
# 23                         34T143
# 24                         34T147
# 25                         34T155
#
#                                         Provider Name State County/Parish  \
# 0                CAREPARTNERS REHABILITATION HOSPITAL    NC      Buncombe
# 1                            CAROLINAS REHABILITATION    NC   Mecklenburg
# 2               NOVANT HEALTH REHABILITATION HOSPITAL    NC       Forsyth
# 3                        HIGH POINT REGIONAL HOSPITAL    NC      Guilford
# 6                       ROWAN REGIONAL MEDICAL CENTER    NC         Rowan
# 7                 LENOIR MEMORIAL HOSPITAL REHAB UNIT    NC        Lenoir
# 8              CAPE FEAR VALLEY REHABILITATION CENTER    NC    Cumberland
# 9                       PITT COUNTY MEMORIAL HOSPITAL    NC          Pitt
# 10                   NORTH CAROLINA BAPTIST HOSPITALS    NC       Forsyth
# 11          NOVANT HEALTH PRESBYTERIAN MEDICAL CENTER    NC   Mecklenburg
# 12                      UNC HOSPITALS INPATIENT REHAB    NC        Orange
# 13                                      WAKEMED REHAB    NC          Wake
# 14                    MOSES H. CONE MEMORIAL HOSPITAL    NC      Guilford
# 16  CAROLINAS MEDICAL CENTER - PINEVILLE REHABILIT...    NC   Mecklenburg
# 18                FIRSTHEALTH MOORE REGIONAL HOSPITAL    NC         Moore
# 19                   DLP FRYE REGIONAL MEDICAL CENTER    NC       Catawba
# 20               CAROLINAEAST REHABILITATION HOSPITAL    NC        Craven
# 21            MARIA PARHAM HEALTHCARE ASSOCIATION INC    NC         Vance
# 22  NEW HANOVER REGIONAL MEDICAL CENTER REHABILITA...    NC   New Hanover
# 23                      CATAWBA VALLEY MEDICAL CENTER    NC       Catawba
# 24           BRYANT T. ALDRIDGE REHABILITATION CENTER    NC          Nash
# 25                           DURHAM REGIONAL HOSPITAL    NC        Durham
#
#     CMS Region       Measure Code  Score
# 0            4  I_013_01_OBS_RATE    0.1
# 1            4  I_013_01_OBS_RATE    0.1
# 2            4  I_013_01_OBS_RATE    0.4
# 3            4  I_013_01_OBS_RATE    0.0
# 6            4  I_013_01_OBS_RATE    0.0
# 7            4  I_013_01_OBS_RATE    0.5
# 8            4  I_013_01_OBS_RATE    0.2
# 9            4  I_013_01_OBS_RATE    0.4
# 10           4  I_013_01_OBS_RATE    0.3
# 11           4  I_013_01_OBS_RATE    0.0
# 12           4  I_013_01_OBS_RATE    0.2
# 13           4  I_013_01_OBS_RATE    0.0
# 14           4  I_013_01_OBS_RATE    0.0
# 16           4  I_013_01_OBS_RATE    0.4
# 18           4  I_013_01_OBS_RATE    0.5
# 19           4  I_013_01_OBS_RATE    0.0
# 20           4  I_013_01_OBS_RATE    0.0
# 21           4  I_013_01_OBS_RATE    0.0
# 22           4  I_013_01_OBS_RATE    0.2
# 23           4  I_013_01_OBS_RATE    0.0
# 24           4  I_013_01_OBS_RATE    0.3
# 25           4  I_013_01_OBS_RATE    0.0

# %%
National_Falls_Rate= National_Data_25.loc[National_Data_25['Measure Code']=='I_013_01_NATL_OBS_RATE']

# %%
National_Falls_Rate=National_Falls_Rate[['CMS Certification Number (CCN)','Measure Code','Score']]
National_Falls_Rate
# Out:
#   CMS Certification Number (CCN)            Measure Code Score
# 3                         NATION  I_013_01_NATL_OBS_RATE   0.2

# %%
Avg_NC_Falls_Rate_25= NC_Falls_25_Rate.groupby('County/Parish')['Score'].mean().to_frame().rename(columns={'Score':'Score_2025'}).reset_index()

# %%
Avg_NC_Falls_Rate_25
# Out:
#    County/Parish  Score_2025
# 0       Buncombe    0.100000
# 1        Catawba    0.000000
# 2         Craven    0.000000
# 3     Cumberland    0.200000
# 4         Durham    0.000000
# 5        Forsyth    0.350000
# 6       Guilford    0.000000
# 7         Lenoir    0.500000
# 8    Mecklenburg    0.166667
# 9          Moore    0.500000
# 10          Nash    0.300000
# 11   New Hanover    0.200000
# 12        Orange    0.200000
# 13          Pitt    0.400000
# 14         Rowan    0.000000
# 15         Vance    0.000000
# 16          Wake    0.000000

# %%
Avg_NC_Falls_Rate_25.to_csv('Avg_NC_Falls_Rate_25.csv', index=False)

# %%
Avg_NC_Falls_Rate_25['Score_2025'].sum()
# Out:
# np.float64(2.9166666666666665)

# %%
Avg_NC_Falls_Rate_25.plot(kind='bar', x='County/Parish', y='Score_2025', figsize=(12,8))

national_average = 0.2
plt.axhline(y=national_average, color='red', linestyle='--', label=f'National Average: {national_average:.2f}')

plt.title('Average Percent of Patients Who Experience At Least One Fall With Major Injury 2025')
plt.xlabel('County Name')
plt.xticks(rotation=45)

plt.ylabel('Avg. Percent of Patients with a Fall')
# Out:
# Text(0, 0.5, 'Avg. Percent of Patients with a Fall')

# %% [markdown]
# #### 2024 Falls

# %%
Provider_data_24.head()
# Out:
#   CMS Certification Number (CCN)  \
# 0                         013025
# 1                         013025
# 2                         013025
# 3                         013025
# 4                         013025
#
#                                        Provider Name       Address Line 1  \
# 0  ENCOMPASS HEALTH LAKESHORE REHABILITATION HOSP...  3800 RIDGEWAY DRIVE
# 1  ENCOMPASS HEALTH LAKESHORE REHABILITATION HOSP...  3800 RIDGEWAY DRIVE
# 2  ENCOMPASS HEALTH LAKESHORE REHABILITATION HOSP...  3800 RIDGEWAY DRIVE
# 3  ENCOMPASS HEALTH LAKESHORE REHABILITATION HOSP...  3800 RIDGEWAY DRIVE
# 4  ENCOMPASS HEALTH LAKESHORE REHABILITATION HOSP...  3800 RIDGEWAY DRIVE
#
#   Address Line 2   City/Town State  ZIP Code County/Parish Telephone Number  \
# 0              -  BIRMINGHAM    AL     35209     Jefferson   (205) 868-2000
# 1              -  BIRMINGHAM    AL     35209     Jefferson   (205) 868-2000
# 2              -  BIRMINGHAM    AL     35209     Jefferson   (205) 868-2000
# 3              -  BIRMINGHAM    AL     35209     Jefferson   (205) 868-2000
# 4              -  BIRMINGHAM    AL     35209     Jefferson   (205) 868-2000
#
#    CMS Region        Measure Code                                     Score  \
# 0           4   I_006_01_CI_LOWER                                     0.773
# 1           4   I_006_01_CI_UPPER                                     3.964
# 2           4  I_006_01_COMP_PERF  No Different than the National Benchmark
# 3           4  I_006_01_DOPC_DAYS                                     2,914
# 4           4  I_006_01_ELIGCASES                                     3.148
#
#   Footnote  Start Date    End Date Measure Date Range
# 0        -  07/01/2022  06/30/2023                  -
# 1        -  07/01/2022  06/30/2023                  -
# 2        -  07/01/2022  06/30/2023                  -
# 3        -  07/01/2022  06/30/2023                  -
# 4        -  07/01/2022  06/30/2023                  -

# %%
NC_Falls_24_Rate= Provider_data_24.loc[(Provider_data_24['Measure Code']=='I_013_01_OBS_RATE') &(Provider_data_24['State']=='NC')].drop(columns=['Address Line 1','Address Line 2', 'City/Town','ZIP Code','Telephone Number','Footnote','Start Date','End Date', 'Measure Date Range']).reset_index(drop=True)
NC_Falls_24_Rate.head()
# Out:
#   CMS Certification Number (CCN)                          Provider Name State  \
# 0                         343025      CAREPARTNERS  REHABILITATION HOSP    NC
# 1                         343026               CAROLINAS REHABILITATION    NC
# 2                         343027  NOVANT HEALTH REHABILITATION HOSPITAL    NC
# 3                         34T004           HIGH POINT REGIONAL HOSPITAL    NC
# 4                         34T008             CENTER FOR INPATIENT REHAB    NC
#
#   County/Parish  CMS Region       Measure Code          Score
# 0      Buncombe           4  I_013_01_OBS_RATE            0.1
# 1   Mecklenburg           4  I_013_01_OBS_RATE            0.0
# 2       Forsyth           4  I_013_01_OBS_RATE            0.3
# 3      Guilford           4  I_013_01_OBS_RATE            0.0
# 4      Scotland           4  I_013_01_OBS_RATE  Not Available

# %%
rows_to_drop= NC_Falls_24_Rate.loc[NC_Falls_24_Rate['Score']=='Not Available']
rows_to_drop
# Out:
#    CMS Certification Number (CCN)                              Provider Name  \
# 4                          34T008                 CENTER FOR INPATIENT REHAB
# 5                          34T014             WHITAKER REHABILITATION CENTER
# 11                         34T053  NOVANT HEALTH PRESBYTERIAN MEDICAL CENTER
# 15                         34T097      REGIONAL REHAB CENTER AT HUGH CHATHAM
# 17                         34T113                   CAROLINAS MEDICAL CENTER
#
#    State County/Parish  CMS Region       Measure Code          Score
# 4     NC      Scotland           4  I_013_01_OBS_RATE  Not Available
# 5     NC       Forsyth           4  I_013_01_OBS_RATE  Not Available
# 11    NC   Mecklenburg           4  I_013_01_OBS_RATE  Not Available
# 15    NC         Surry           4  I_013_01_OBS_RATE  Not Available
# 17    NC   Mecklenburg           4  I_013_01_OBS_RATE  Not Available

# %%
NC_Falls_24_Rate= NC_Falls_24_Rate.drop(rows_to_drop.index, axis=0).reset_index()

# %%
NC_Falls_24_Rate['Score']=NC_Falls_24_Rate['Score'].astype(str).astype(float)

# %%
Avg_NC_Falls_Rate_24= NC_Falls_24_Rate.groupby('County/Parish')['Score'].mean().to_frame().rename(columns={'Score':'Score_2024'})

# %%
Avg_NC_Falls_Rate_24=Avg_NC_Falls_Rate_24.reset_index()
Avg_NC_Falls_Rate_24
# Out:
#    County/Parish  Score_2024
# 0       Buncombe        0.10
# 1        Catawba        0.65
# 2         Craven        0.50
# 3     Cumberland        0.20
# 4         Durham        0.00
# 5        Forsyth        0.15
# 6       Guilford        0.10
# 7         Lenoir        0.00
# 8    Mecklenburg        0.00
# 9          Moore        0.00
# 10          Nash        0.00
# 11   New Hanover        0.00
# 12        Orange        0.00
# 13          Pitt        0.00
# 14         Rowan        0.00
# 15         Vance        0.00
# 16          Wake        0.00

# %%
National_Falls_Rate_24= National_Data_24.loc[National_Data_24['Measure Code']=='I_013_01_NATL_OBS_RATE']
National_Falls_Rate_24
# Out:
#   CMS Certification Number (CCN)            Measure Code Score Footnote  \
# 6                         NATION  I_013_01_NATL_OBS_RATE   0.2        -
#
#   Start Date   End Date Measure Date Range
# 6  10/1/2022  9/30/2023                  -

# %%
Avg_NC_Falls_Rate_24.plot(kind='bar', x='County/Parish', y='Score_2024')

national_average = 0.2
plt.axhline(y=national_average, color='red', linestyle='--', label=f'National Average: {national_average:.2f}')

plt.title('Average Percent of Patients Who Experience At Least One Fall With Major Injury 2024')
plt.xlabel('County')
plt.ylabel('Avg. Percent of Patients with a Fall')
# Out:
# Text(0, 0.5, 'Avg. Percent of Patients with a Fall')

# %%
Falls_23= Provider_data_23.loc[(Provider_data_23['Measure Code']=='I_013_01_OBS_RATE') | (Provider_data_23['Measure Code']=='I_013_01_NUMERATOR') | (Provider_data_23['Measure Code']=='I_013_01_DENOMINATOR')]

# %%
Falls_23.head()
# Out:
#    CMS Certification Number (CCN)  \
# 10                         013025
# 11                         013025
# 12                         013025
# 78                         013028
# 79                         013028
#
#                                         Facility Name       Address Line 1  \
# 10  ENCOMPASS HEALTH LAKESHORE REHABILITATION HOSP...  3800 RIDGEWAY DRIVE
# 11  ENCOMPASS HEALTH LAKESHORE REHABILITATION HOSP...  3800 RIDGEWAY DRIVE
# 12  ENCOMPASS HEALTH LAKESHORE REHABILITATION HOSP...  3800 RIDGEWAY DRIVE
# 78    ENCOMPASS REHABILITATION HOSPITAL OF MONTGOMERY  4465 NARROW LANE RD
# 79    ENCOMPASS REHABILITATION HOSPITAL OF MONTGOMERY  4465 NARROW LANE RD
#
#    Address Line 2        City State  Zip Code County Name    Phone Number  \
# 10              -  BIRMINGHAM    AL     35209   Jefferson  (205) 868-2000
# 11              -  BIRMINGHAM    AL     35209   Jefferson  (205) 868-2000
# 12              -  BIRMINGHAM    AL     35209   Jefferson  (205) 868-2000
# 78              -  MONTGOMERY    AL     36116  Montgomery  (334) 284-7821
# 79              -  MONTGOMERY    AL     36116  Montgomery  (334) 284-7821
#
#     CMS Region          Measure Code Score Footnote  Start Date    End Date  \
# 10           4  I_013_01_DENOMINATOR  1876        -  10/01/2021  09/30/2022
# 11           4    I_013_01_NUMERATOR     0        -  10/01/2021  09/30/2022
# 12           4     I_013_01_OBS_RATE   0.0        -  10/01/2021  09/30/2022
# 78           4  I_013_01_DENOMINATOR  1576        -  10/01/2021  09/30/2022
# 79           4    I_013_01_NUMERATOR     1        -  10/01/2021  09/30/2022
#
#    Measure Date Range
# 10                  -
# 11                  -
# 12                  -
# 78                  -
# 79                  -

# %%
NC_Falls_23_Rate= Falls_23.loc[(Falls_23['Measure Code']=='I_013_01_OBS_RATE')& (Falls_23['State']=='NC')].drop(columns=['Address Line 1','Address Line 2', 'City','Zip Code','Phone Number','Footnote','Start Date','End Date', 'Measure Date Range']).reset_index(drop=True)
NC_Falls_23_Rate
# Out:
#    CMS Certification Number (CCN)  \
# 0                          343025
# 1                          343026
# 2                          343027
# 3                          34T004
# 4                          34T008
# 5                          34T014
# 6                          34T015
# 7                          34T027
# 8                          34T028
# 9                          34T040
# 10                         34T047
# 11                         34T061
# 12                         34T069
# 13                         34T091
# 14                         34T097
# 15                         34T098
# 16                         34T113
# 17                         34T115
# 18                         34T116
# 19                         34T131
# 20                         34T132
# 21                         34T141
# 22                         34T143
# 23                         34T147
# 24                         34T155
#
#                                         Facility Name State  County Name  \
# 0                   CAREPARTNERS  REHABILITATION HOSP    NC     Buncombe
# 1                            CAROLINAS REHABILITATION    NC  Mecklenburg
# 2               NOVANT HEALTH REHABILITATION HOSPITAL    NC      Forsyth
# 3                        HIGH POINT REGIONAL HOSPITAL    NC     Guilford
# 4                          CENTER FOR INPATIENT REHAB    NC     Scotland
# 5                      WHITAKER REHABILITATION CENTER    NC      Forsyth
# 6                       ROWAN REGIONAL MEDICAL CENTER    NC        Rowan
# 7                 LENOIR MEMORIAL HOSPITAL REHAB UNIT    NC       Lenoir
# 8              CAPE FEAR VALLEY REHABILITATION CENTER    NC   Cumberland
# 9                       PITT COUNTY MEMORIAL HOSPITAL    NC         Pitt
# 10                   NORTH CAROLINA BAPTIST HOSPITALS    NC      Forsyth
# 11                      UNC HOSPITALS INPATIENT REHAB    NC       Orange
# 12                                      WAKEMED REHAB    NC         Wake
# 13                    MOSES H. CONE MEMORIAL HOSPITAL    NC     Guilford
# 14              REGIONAL REHAB CENTER AT HUGH CHATHAM    NC        Surry
# 15  CAROLINAS MEDICAL CENTER - PINEVILLE REHABILIT...    NC  Mecklenburg
# 16                           CAROLINAS MEDICAL CENTER    NC  Mecklenburg
# 17                FIRSTHEALTH MOORE REGIONAL HOSPITAL    NC        Moore
# 18                   DLP FRYE REGIONAL MEDICAL CENTER    NC      Catawba
# 19               CAROLINAEAST REHABILITATION HOSPITAL    NC       Craven
# 20            MARIA PARHAM HEALTHCARE ASSOCIATION INC    NC        Vance
# 21  NEW HANOVER REGIONAL MEDICAL CENTER REHABILITA...    NC  New Hanover
# 22                      CATAWBA VALLEY MEDICAL CENTER    NC      Catawba
# 23           BRYANT T. ALDRIDGE REHABILITATION CENTER    NC         Nash
# 24                           DURHAM REGIONAL HOSPITAL    NC       Durham
#
#     CMS Region       Measure Code          Score
# 0            4  I_013_01_OBS_RATE            0.2
# 1            4  I_013_01_OBS_RATE            0.2
# 2            4  I_013_01_OBS_RATE            0.2
# 3            4  I_013_01_OBS_RATE            0.0
# 4            4  I_013_01_OBS_RATE  Not Available
# 5            4  I_013_01_OBS_RATE  Not Available
# 6            4  I_013_01_OBS_RATE            0.0
# 7            4  I_013_01_OBS_RATE            0.0
# 8            4  I_013_01_OBS_RATE            0.0
# 9            4  I_013_01_OBS_RATE            0.0
# 10           4  I_013_01_OBS_RATE            0.3
# 11           4  I_013_01_OBS_RATE            0.3
# 12           4  I_013_01_OBS_RATE            0.0
# 13           4  I_013_01_OBS_RATE            0.0
# 14           4  I_013_01_OBS_RATE  Not Available
# 15           4  I_013_01_OBS_RATE            0.0
# 16           4  I_013_01_OBS_RATE  Not Available
# 17           4  I_013_01_OBS_RATE            0.0
# 18           4  I_013_01_OBS_RATE            0.0
# 19           4  I_013_01_OBS_RATE            0.0
# 20           4  I_013_01_OBS_RATE            0.0
# 21           4  I_013_01_OBS_RATE            0.2
# 22           4  I_013_01_OBS_RATE            0.0
# 23           4  I_013_01_OBS_RATE            0.0
# 24           4  I_013_01_OBS_RATE            0.0

# %%
rows_to_drop= NC_Falls_23_Rate.loc[NC_Falls_23_Rate['Score']=='Not Available']

# %%
NC_Falls_23_Rate= NC_Falls_23_Rate.drop(rows_to_drop.index, axis=0).reset_index()

# %%
NC_Falls_23_Rate['Score']=NC_Falls_23_Rate['Score'].astype(str).astype(float)
NC_Falls_23_Rate
# Out:
#     index CMS Certification Number (CCN)  \
# 0       0                         343025
# 1       1                         343026
# 2       2                         343027
# 3       3                         34T004
# 4       6                         34T015
# 5       7                         34T027
# 6       8                         34T028
# 7       9                         34T040
# 8      10                         34T047
# 9      11                         34T061
# 10     12                         34T069
# 11     13                         34T091
# 12     15                         34T098
# 13     17                         34T115
# 14     18                         34T116
# 15     19                         34T131
# 16     20                         34T132
# 17     21                         34T141
# 18     22                         34T143
# 19     23                         34T147
# 20     24                         34T155
#
#                                         Facility Name State  County Name  \
# 0                   CAREPARTNERS  REHABILITATION HOSP    NC     Buncombe
# 1                            CAROLINAS REHABILITATION    NC  Mecklenburg
# 2               NOVANT HEALTH REHABILITATION HOSPITAL    NC      Forsyth
# 3                        HIGH POINT REGIONAL HOSPITAL    NC     Guilford
# 4                       ROWAN REGIONAL MEDICAL CENTER    NC        Rowan
# 5                 LENOIR MEMORIAL HOSPITAL REHAB UNIT    NC       Lenoir
# 6              CAPE FEAR VALLEY REHABILITATION CENTER    NC   Cumberland
# 7                       PITT COUNTY MEMORIAL HOSPITAL    NC         Pitt
# 8                    NORTH CAROLINA BAPTIST HOSPITALS    NC      Forsyth
# 9                       UNC HOSPITALS INPATIENT REHAB    NC       Orange
# 10                                      WAKEMED REHAB    NC         Wake
# 11                    MOSES H. CONE MEMORIAL HOSPITAL    NC     Guilford
# 12  CAROLINAS MEDICAL CENTER - PINEVILLE REHABILIT...    NC  Mecklenburg
# 13                FIRSTHEALTH MOORE REGIONAL HOSPITAL    NC        Moore
# 14                   DLP FRYE REGIONAL MEDICAL CENTER    NC      Catawba
# 15               CAROLINAEAST REHABILITATION HOSPITAL    NC       Craven
# 16            MARIA PARHAM HEALTHCARE ASSOCIATION INC    NC        Vance
# 17  NEW HANOVER REGIONAL MEDICAL CENTER REHABILITA...    NC  New Hanover
# 18                      CATAWBA VALLEY MEDICAL CENTER    NC      Catawba
# 19           BRYANT T. ALDRIDGE REHABILITATION CENTER    NC         Nash
# 20                           DURHAM REGIONAL HOSPITAL    NC       Durham
#
#     CMS Region       Measure Code  Score
# 0            4  I_013_01_OBS_RATE    0.2
# 1            4  I_013_01_OBS_RATE    0.2
# 2            4  I_013_01_OBS_RATE    0.2
# 3            4  I_013_01_OBS_RATE    0.0
# 4            4  I_013_01_OBS_RATE    0.0
# 5            4  I_013_01_OBS_RATE    0.0
# 6            4  I_013_01_OBS_RATE    0.0
# 7            4  I_013_01_OBS_RATE    0.0
# 8            4  I_013_01_OBS_RATE    0.3
# 9            4  I_013_01_OBS_RATE    0.3
# 10           4  I_013_01_OBS_RATE    0.0
# 11           4  I_013_01_OBS_RATE    0.0
# 12           4  I_013_01_OBS_RATE    0.0
# 13           4  I_013_01_OBS_RATE    0.0
# 14           4  I_013_01_OBS_RATE    0.0
# 15           4  I_013_01_OBS_RATE    0.0
# 16           4  I_013_01_OBS_RATE    0.0
# 17           4  I_013_01_OBS_RATE    0.2
# 18           4  I_013_01_OBS_RATE    0.0
# 19           4  I_013_01_OBS_RATE    0.0
# 20           4  I_013_01_OBS_RATE    0.0

# %%
Avg_NC_Falls_Rate_23= NC_Falls_23_Rate.groupby('County Name')['Score'].mean().to_frame().reset_index()

# %%
Avg_NC_Falls_Rate_23=Avg_NC_Falls_Rate_23.rename(columns={'County Name':'County/Parish','Score':'Score_2023'})
Avg_NC_Falls_Rate_23
# Out:
#    County/Parish  Score_2023
# 0       Buncombe        0.20
# 1        Catawba        0.00
# 2         Craven        0.00
# 3     Cumberland        0.00
# 4         Durham        0.00
# 5        Forsyth        0.25
# 6       Guilford        0.00
# 7         Lenoir        0.00
# 8    Mecklenburg        0.10
# 9          Moore        0.00
# 10          Nash        0.00
# 11   New Hanover        0.20
# 12        Orange        0.30
# 13          Pitt        0.00
# 14         Rowan        0.00
# 15         Vance        0.00
# 16          Wake        0.00

# %%
National_Falls_Rate_23=National_Data_23.loc[National_Data_23['Measure Code']=='I_013_01_NATL_OBS_RATE']
National_Falls_Rate_23
# Out:
#   CMS Certification Number (CCN)            Measure Code Score Footnote  \
# 6                         NATION  I_013_01_NATL_OBS_RATE   0.1        -
#
#   Start Date   End Date Measure Date Range
# 6  10/1/2021  9/30/2022                  -

# %%
Avg_NC_Falls_Rate_23.plot(kind='bar', x='County/Parish', y='Score_2023')

national_average = 0.1
plt.axhline(y=national_average, color='red', linestyle='--', label=f'National Average: {national_average:.2f}')

plt.title('Average Percent of Patients Who Experience At Least One Fall With Major Injury 2023')
plt.xlabel('County')
plt.ylabel('Avg. Percent of Patients with a Fall')
# Out:
# Text(0, 0.5, 'Avg. Percent of Patients with a Fall')

# %%
dfs=[Avg_NC_Falls_Rate_23, Avg_NC_Falls_Rate_24, Avg_NC_Falls_Rate_25]

Avg_NC_Falls_Merged = dfs[0]

for i in range(1, len(dfs)):
    Avg_NC_Falls_Merged= pd.merge(Avg_NC_Falls_Merged, dfs[i], on = 'County/Parish', how ='inner')


Avg_NC_Falls_Merged
# Out:
#    County/Parish  Score_2023  Score_2024  Score_2025
# 0       Buncombe        0.20        0.10    0.100000
# 1        Catawba        0.00        0.65    0.000000
# 2         Craven        0.00        0.50    0.000000
# 3     Cumberland        0.00        0.20    0.200000
# 4         Durham        0.00        0.00    0.000000
# 5        Forsyth        0.25        0.15    0.350000
# 6       Guilford        0.00        0.10    0.000000
# 7         Lenoir        0.00        0.00    0.500000
# 8    Mecklenburg        0.10        0.00    0.166667
# 9          Moore        0.00        0.00    0.500000
# 10          Nash        0.00        0.00    0.300000
# 11   New Hanover        0.20        0.00    0.200000
# 12        Orange        0.30        0.00    0.200000
# 13          Pitt        0.00        0.00    0.400000
# 14         Rowan        0.00        0.00    0.000000
# 15         Vance        0.00        0.00    0.000000
# 16          Wake        0.00        0.00    0.000000

# %%
Avg_NC_Falls_Merged.to_csv('Avg_NC_Falls_Merged.csv', index=False)

# %%
overall_avg_fall_rate_23= ((Avg_NC_Falls_Merged['Score_2023'].sum())/17)
overall_avg_fall_rate_23
# Out:
# np.float64(0.061764705882352944)

# %%
overall_avg_fall_rate_24= (Avg_NC_Falls_Merged['Score_2024'].sum())/17
overall_avg_fall_rate_24
# Out:
# np.float64(0.09999999999999999)

# %%
overall_avg_fall_rate_25= (Avg_NC_Falls_Merged['Score_2025'].sum())/17
overall_avg_fall_rate_25
# Out:
# np.float64(0.1715686274509804)
