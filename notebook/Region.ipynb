# %%
import pandas as pd

# %%
race_age_groups_23=pd.read_csv('../data/Race_Age_Groups_23_CSV.csv')

# %%
race_age_groups_24=pd.read_csv('../data/Race_Age_Groups_24_CSV.csv')

# %%
race_age_groups_25=pd.read_csv('../data/Race_Age_Groups_25_CSV.csv')

# %%
race_age_groups_23.head(3)
# Out:
#     fips     County                  Region  \
# 0  37019  Brunswick  Eastern North Carolina
# 1    NaN    34.120"                Estimate
# 2  37025   Cabarrus  Central North Carolina
#
#                                  COG                                    MSA  \
# 0   Cape Fear Council of Governments                             Wilmington
# 1                               2023  34.03887554891685, -78.22740741677175
# 2  Centralina Council of Governments        Charlotte-Concord-Gastonia (NC)
#
#      Year   Race  Group N  Age 0 to 2  Age 3 to 4  ...     medage  \
# 0  2023.0  Other      1.0       269.0       156.0  ...  47.910000
# 1     NaN    NaN      NaN         NaN         NaN  ...        NaN
# 2  2023.0  Other      1.0       960.0       581.0  ...  20.226829
#
#    Age 0 to 17  Age 18 to 24  Age 25 to 44  Age 45 to 64  Age 65 Plus  \
# 0       1448.0         395.0         881.0        1317.0       1684.0
# 1          NaN           NaN           NaN           NaN          NaN
# 2       5183.0        1245.0        2469.0        1816.0        614.0
#
#                                                 geom  Estimate/Projection  \
# 0  {"coordinates":[[[[-78.16235,34.357006999],[-7...                  NaN
# 1                                                NaN                  NaN
# 2  {"coordinates":[[[[-80.784167,35.506016999],[-...             Estimate
#
#    Vintage                           geo_point_2d
# 0      NaN                                    NaN
# 1      NaN                                    NaN
# 2   2023.0  35.38678374966464, -80.55187904089568
#
# [3 rows x 38 columns]

# %%
race_age_groups_23.columns
# Out:
# Index(['fips', 'County', 'Region', 'COG', 'MSA', 'Year', 'Race', 'Group N',
#        'Age 0 to 2', 'Age 3 to 4', 'Age 5', 'Age 6 to 9', 'Age 10 to 13',
#        'Age 14', 'Age 15', 'Age 16 to 17', 'Age 18 to 19', 'Age 20 to 24',
#        'Age 25 to 34', 'Age 35 to 44', 'Age 45 to 54', 'Age 55 to 59',
#        'Age 60 to 64', 'Age 65 to 74', 'Age 75 to 84', 'Age 85 to 99',
#        'Age 100', 'Total', 'medage', 'Age 0 to 17', 'Age 18 to 24',
#        'Age 25 to 44', 'Age 45 to 64', 'Age 65 Plus', 'geom',
#        'Estimate/Projection', 'Vintage', 'geo_point_2d'],
#       dtype='object')

# %%
region_NC_23=race_age_groups_23[['County','Region','Age 65 Plus','Total','Year']]
region_NC_23
# Out:
#         County                  Region  Age 65 Plus    Total    Year
# 0    Brunswick  Eastern North Carolina       1684.0   5725.0  2023.0
# 1      34.120"                Estimate          NaN      NaN     NaN
# 2     Cabarrus  Central North Carolina        614.0  11327.0  2023.0
# 3     Alamance  Central North Carolina       6115.0  38581.0  2023.0
# 4    Brunswick  Eastern North Carolina       3215.0  13027.0  2023.0
# ..         ...                     ...          ...      ...     ...
# 620   Estimate                    2023          NaN      NaN     NaN
# 621      Macon  Western North Carolina      10791.0  35524.0  2023.0
# 622   Estimate                    2023          NaN      NaN     NaN
# 623    Tyrrell  Eastern North Carolina        614.0   2225.0  2023.0
# 624      Surry  Western North Carolina        530.0   2867.0  2023.0
#
# [625 rows x 5 columns]

# %%
NC_IRF_Counties_List=['Buncombe','Catawba','Craven','Cumberland','Durham','Forsyth','Guilford','Lenoir','Mecklenburg','Moore','Nash','New_Hanover','Orange','Pitt','Rowan','Vance','Wake']

# %%
region_NC_23= region_NC_23[region_NC_23['County'].isin(NC_IRF_Counties_List)]
region_NC_23
# Out:
#        County                  Region  Age 65 Plus     Total    Year
# 16    Catawba  Western North Carolina       1091.0    7825.0  2023.0
# 24     Craven  Eastern North Carolina        679.0    3802.0  2023.0
# 50   Guilford  Central North Carolina       3123.0   32699.0  2023.0
# 59   Buncombe  Western North Carolina      54841.0  241346.0  2023.0
# 74   Buncombe  Western North Carolina       2797.0   16517.0  2023.0
# ..        ...                     ...          ...       ...     ...
# 564  Guilford  Central North Carolina       1054.0   22430.0  2023.0
# 567   Forsyth  Central North Carolina       1133.0   11241.0  2023.0
# 568     Rowan  Central North Carolina      22785.0  117253.0  2023.0
# 573   Forsyth  Central North Carolina      52299.0  259712.0  2023.0
# 584    Durham  Central North Carolina      29830.0  182995.0  2023.0
#
# [80 rows x 5 columns]

# %%
region_NC_23['Pct 65 plus']= (region_NC_23['Age 65 Plus']/region_NC_23['Total']) * 100
region_NC_23
# Out:
# C:\Users\vgcar\AppData\Local\Temp\ipykernel_29488\4113607466.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   region_NC_23['Pct 65 plus']= (region_NC_23['Age 65 Plus']/region_NC_23['Total']) * 100
#        County                  Region  Age 65 Plus     Total    Year  \
# 16    Catawba  Western North Carolina       1091.0    7825.0  2023.0
# 24     Craven  Eastern North Carolina        679.0    3802.0  2023.0
# 50   Guilford  Central North Carolina       3123.0   32699.0  2023.0
# 59   Buncombe  Western North Carolina      54841.0  241346.0  2023.0
# 74   Buncombe  Western North Carolina       2797.0   16517.0  2023.0
# ..        ...                     ...          ...       ...     ...
# 564  Guilford  Central North Carolina       1054.0   22430.0  2023.0
# 567   Forsyth  Central North Carolina       1133.0   11241.0  2023.0
# 568     Rowan  Central North Carolina      22785.0  117253.0  2023.0
# 573   Forsyth  Central North Carolina      52299.0  259712.0  2023.0
# 584    Durham  Central North Carolina      29830.0  182995.0  2023.0
#
#      Pct 65 plus
# 16     13.942492
# 24     17.859022
# 50      9.550751
# 59     22.722979
# 74     16.934068
# ..           ...
# 564     4.699064
# 567    10.079174
# 568    19.432339
# 573    20.137306
# 584    16.300992
#
# [80 rows x 6 columns]

# %%
region_NC_23_totalpop=region_NC_23.groupby('Region')['Total'].sum()
region_NC_23_totalpop
# Out:
# Region
# Central North Carolina    4090082.0
# Eastern North Carolina     768185.0
# Western North Carolina     443243.0
# Name: Total, dtype: float64

# %%
region_NC_23_totalpop=region_NC_23_totalpop.to_frame()
region_NC_23_totalpop
# Out:
#                             Total
# Region
# Central North Carolina  4090082.0
# Eastern North Carolina   768185.0
# Western North Carolina   443243.0

# %%
region_NC_23_pct65= region_NC_23.groupby('Region')['Age 65 Plus'].sum().to_frame()
region_NC_23_pct65
# Out:
#                         Age 65 Plus
# Region
# Central North Carolina     597310.0
# Eastern North Carolina     124416.0
# Western North Carolina      92030.0

# %%
region_NC_23_pct65=region_NC_23_pct65.rename(columns={'Age 65 Plus':'Age 65 Plus 2023'})
region_NC_23_pct65
# Out:
#                         Age 65 Plus 2023
# Region
# Central North Carolina          597310.0
# Eastern North Carolina          124416.0
# Western North Carolina           92030.0

# %%
pct_65plus_by_region_23=pd.merge(region_NC_23_pct65, region_NC_23_totalpop,
                      on='Region',
                      how='inner')
pct_65plus_by_region_23
# Out:
#                         Age 65 Plus 2023      Total
# Region
# Central North Carolina          597310.0  4090082.0
# Eastern North Carolina          124416.0   768185.0
# Western North Carolina           92030.0   443243.0

# %%
pct_65plus_by_region_23['pct 65 plus']=(pct_65plus_by_region_23['Age 65 Plus 2023'])/(pct_65plus_by_region_23['Total']) * 100
pct_65plus_by_region_23
# Out:
#                         Age 65 Plus 2023      Total  pct 65 plus
# Region
# Central North Carolina          597310.0  4090082.0    14.603864
# Eastern North Carolina          124416.0   768185.0    16.196099
# Western North Carolina           92030.0   443243.0    20.762877

# %%
pct_65plus_by_region_23.to_csv('pct_65plus_by_region_23.csv', index=True)

# %%
race_age_groups_25
# Out:
#       fips     County                  Region  \
# 0    37003  Alexander  Western North Carolina
# 1    37001   Alamance  Central North Carolina
# 2    37023      Burke  Western North Carolina
# 3      NaN        NaN                     NaN
# 4      149       35."              Projection
# ..     ...        ...                     ...
# 824  37147       Pitt  Eastern North Carolina
# 825    NaN        NaN                     NaN
# 826      7     35.50"              Projection
# 827  37183       Wake  Central North Carolina
# 828  37159      Rowan  Central North Carolina
#
#                                          COG  \
# 0    Western Piedmont Council of Governments
# 1      Piedmont Triad Council of Governments
# 2    Western Piedmont Council of Governments
# 3                                        NaN
# 4                                       2024
# ..                                       ...
# 824                      Mid-East Commission
# 825                                      NaN
# 826                                     2024
# 827           Central Pines Regional Council
# 828        Centralina Council of Governments
#
#                                        MSA    Year                      Race  \
# 0                 Hickory-Lenoir-Morganton  2025.0  Asian & Pacific Islander
# 1                               Burlington  2025.0                     Other
# 2                 Hickory-Lenoir-Morganton  2025.0                     Black
# 3                                      NaN     NaN                       NaN
# 4    35.74961065992926, -81.70477863312823     NaN                       NaN
# ..                                     ...     ...                       ...
# 824                             Greenville  2025.0                     Black
# 825                                    NaN     NaN                       NaN
# 826  35.59329885449204, -77.37449649585241     NaN                       NaN
# 827                           Raleigh-Cary  2025.0  Asian & Pacific Islander
# 828        Charlotte-Concord-Gastonia (NC)  2025.0                     Black
#
#      Group N  Age 0 to 2  Age 3 to 4  ...     medage  Age 0 to 17  \
# 0        1.0        17.0        12.0  ...  34.272727        100.0
# 1        1.0       690.0       444.0  ...  17.453125       4449.0
# 2        1.0       123.0        91.0  ...  36.940299       1190.0
# 3        NaN         NaN         NaN  ...        NaN          NaN
# 4        NaN         NaN         NaN  ...        NaN          NaN
# ..       ...         ...         ...  ...        ...          ...
# 824      1.0      2643.0      1755.0  ...  34.071379      15643.0
# 825      NaN         NaN         NaN  ...        NaN          NaN
# 826      NaN         NaN         NaN  ...        NaN          NaN
# 827      1.0      3425.0      2093.0  ...  39.725061      23218.0
# 828      1.0       819.0       581.0  ...  36.307317       5868.0
#
#      Age 18 to 24  Age 25 to 44  Age 45 to 64  Age 65 Plus  \
# 0            38.0         171.0          94.0         35.0
# 1          1080.0        1997.0         942.0        220.0
# 2           723.0        1001.0        1317.0        953.0
# 3             NaN           NaN           NaN          NaN
# 4             NaN           NaN           NaN          NaN
# ..            ...           ...           ...          ...
# 824        8437.0       20297.0       12946.0       8576.0
# 825           NaN           NaN           NaN          NaN
# 826           NaN           NaN           NaN          NaN
# 827       12272.0       41271.0       37225.0      12371.0
# 828        2606.0        7169.0        5880.0       3659.0
#
#                                                   geom  Estimate/Projection  \
# 0    {"coordinates":[[[[-81.328324,35.996582999],[-...           Projection
# 1    {"coordinates":[[[[-79.53241,36.241462999],[-7...           Projection
# 2    {"coordinates":[[[[-81.943188,35.960049999],[-...                  NaN
# 3                                                  NaN                  NaN
# 4                                                  NaN                  NaN
# ..                                                 ...                  ...
# 824  {"coordinates":[[[[-77.700692,35.652294999],[-...                  NaN
# 825                                                NaN                  NaN
# 826                                                NaN                  NaN
# 827  {"coordinates":[[[[-78.751273,36.070833999],[-...           Projection
# 828  {"coordinates":[[[[-80.707824,35.852960999],[-...           Projection
#
#      Vintage                            geo_point_2d
# 0     2024.0  35.921026310411975, -81.17702681231853
# 1     2024.0   36.04370973725824, -79.39942485544303
# 2        NaN                                     NaN
# 3        NaN                                     NaN
# 4        NaN                                     NaN
# ..       ...                                     ...
# 824      NaN                                     NaN
# 825      NaN                                     NaN
# 826      NaN                                     NaN
# 827   2024.0   35.79031331872891, -78.65028009124825
# 828   2024.0   35.63942562816136, -80.52474972960941
#
# [829 rows x 38 columns]

# %%
region_NC_25=race_age_groups_25[['County','Region','Age 65 Plus','Total']]
region_NC_25
# Out:
#         County                  Region  Age 65 Plus     Total
# 0    Alexander  Western North Carolina         35.0     438.0
# 1     Alamance  Central North Carolina        220.0    8688.0
# 2        Burke  Western North Carolina        953.0    5184.0
# 3          NaN                     NaN          NaN       NaN
# 4         35."              Projection          NaN       NaN
# ..         ...                     ...          ...       ...
# 824       Pitt  Eastern North Carolina       8576.0   65899.0
# 825        NaN                     NaN          NaN       NaN
# 826     35.50"              Projection          NaN       NaN
# 827       Wake  Central North Carolina      12371.0  126357.0
# 828      Rowan  Central North Carolina       3659.0   25182.0
#
# [829 rows x 4 columns]

# %%
region_NC_25= region_NC_25[region_NC_25['County'].isin(NC_IRF_Counties_List)]
region_NC_25
# Out:
#          County                  Region  Age 65 Plus     Total
# 19   Cumberland  Eastern North Carolina      25406.0  161147.0
# 40       Lenoir  Eastern North Carolina       7133.0   29126.0
# 43      Forsyth  Central North Carolina        490.0   17861.0
# 59   Cumberland  Eastern North Carolina        818.0    7080.0
# 73     Buncombe  Western North Carolina      57666.0  245397.0
# ..          ...                     ...          ...       ...
# 780      Durham  Central North Carolina       2115.0   19899.0
# 781       Vance  Central North Carolina         57.0    1312.0
# 824        Pitt  Eastern North Carolina       8576.0   65899.0
# 827        Wake  Central North Carolina      12371.0  126357.0
# 828       Rowan  Central North Carolina       3659.0   25182.0
#
# [80 rows x 4 columns]

# %%
region_NC_25_totalpop=region_NC_25.groupby('Region')['Total'].sum().to_frame()
region_NC_25_totalpop
# Out:
#                             Total
# Region
# Central North Carolina  4202985.0
# Eastern North Carolina   770585.0
# Western North Carolina   452938.0

# %%
region_NC_25_pct65= region_NC_23.groupby('Region')['Age 65 Plus'].sum().to_frame()
region_NC_25_pct65
# Out:
#                         Age 65 Plus
# Region
# Central North Carolina     597310.0
# Eastern North Carolina     124416.0
# Western North Carolina      92030.0

# %%
region_NC_25_pct65=region_NC_25_pct65.rename(columns={'Age 65 Plus':'Age 65 Plus 2025'})
region_NC_25_pct65
# Out:
#                         Age 65 Plus 2025
# Region
# Central North Carolina          597310.0
# Eastern North Carolina          124416.0
# Western North Carolina           92030.0

# %%
pct65plus_region_25=pd.merge(region_NC_25_totalpop,region_NC_25_pct65,
                             on='Region',
                             how= 'inner')
pct65plus_region_25
# Out:
#                             Total  Age 65 Plus 2025
# Region
# Central North Carolina  4202985.0          597310.0
# Eastern North Carolina   770585.0          124416.0
# Western North Carolina   452938.0           92030.0

# %%
pct65plus_region_25['pct 65 plus']= (pct65plus_region_25['Age 65 Plus 2025']/pct65plus_region_25['Total']) * 100
pct65plus_region_25
# Out:
#                    Region      Total  Age 65 Plus 2025  pct 65 plus
# 0  Central North Carolina  4202985.0          597310.0    14.211566
# 1  Eastern North Carolina   770585.0          124416.0    16.145656
# 2  Western North Carolina   452938.0           92030.0    20.318454

# %%
pct65plus_region_25=pct65plus_region_25.reset_index()
pct65plus_region_25
# Out:
#    index                  Region      Total  Age 65 Plus 2025  pct 65 plus
# 0      0  Central North Carolina  4202985.0          597310.0    14.211566
# 1      1  Eastern North Carolina   770585.0          124416.0    16.145656
# 2      2  Western North Carolina   452938.0           92030.0    20.318454

# %%
pct65plus_region_25.to_csv('pct65plus_region_25.csv', index=False)

# %% [markdown]
# growth: 65plus 25- 65plus23/65plus23

# %%
pct_65plus_by_region_23
# Out:
#                         Age 65 Plus 2023      Total  pct 65 plus
# Region
# Central North Carolina          597310.0  4090082.0    14.603864
# Eastern North Carolina          124416.0   768185.0    16.196099
# Western North Carolina           92030.0   443243.0    20.762877

# %%
race_age_groups_23.head(1)
# Out:
#     fips     County                  Region                               COG  \
# 0  37019  Brunswick  Eastern North Carolina  Cape Fear Council of Governments
#
#           MSA    Year   Race  Group N  Age 0 to 2  Age 3 to 4  ...  medage  \
# 0  Wilmington  2023.0  Other      1.0       269.0       156.0  ...   47.91
#
#    Age 0 to 17  Age 18 to 24  Age 25 to 44  Age 45 to 64  Age 65 Plus  \
# 0       1448.0         395.0         881.0        1317.0       1684.0
#
#                                                 geom  Estimate/Projection  \
# 0  {"coordinates":[[[[-78.16235,34.357006999],[-7...                  NaN
#
#    Vintage  geo_point_2d
# 0      NaN           NaN
#
# [1 rows x 38 columns]

# %%
region_grouped_23=race_age_groups_23[['County','Region','Year','Race','Age 65 Plus', 'Total']]

# %%
region_grouped_23
# Out:
#         County                  Region    Year   Race  Age 65 Plus    Total
# 0    Brunswick  Eastern North Carolina  2023.0  Other       1684.0   5725.0
# 1      34.120"                Estimate     NaN    NaN          NaN      NaN
# 2     Cabarrus  Central North Carolina  2023.0  Other        614.0  11327.0
# 3     Alamance  Central North Carolina  2023.0  Black       6115.0  38581.0
# 4    Brunswick  Eastern North Carolina  2023.0  Black       3215.0  13027.0
# ..         ...                     ...     ...    ...          ...      ...
# 620   Estimate                    2023     NaN    NaN          NaN      NaN
# 621      Macon  Western North Carolina  2023.0  White      10791.0  35524.0
# 622   Estimate                    2023     NaN    NaN          NaN      NaN
# 623    Tyrrell  Eastern North Carolina  2023.0  White        614.0   2225.0
# 624      Surry  Western North Carolina  2023.0  Black        530.0   2867.0
#
# [625 rows x 6 columns]

# %%
#region_grouped_23=new_race_age_groups_23[new_race_age_groups_23['County'].isin(NC_IRF_Counties_List)]
#region_grouped_23

# %% [markdown]
# region_grouped_23 = new_race_age_groups_23.groupby('Region').agg({'Age 65 Plus':'sum',
#                                                                   'Total':'sum'})
# region_grouped_23

# %%
region_grouped_24=race_age_groups_24[['County','Region','Year','Race','Age 65 Plus', 'Total']]
region_grouped_24
# Out:
#          County                  Region    Year                      Race  \
# 0     Alleghany  Western North Carolina  2024.0                     White
# 1     Alleghany  Western North Carolina  2024.0                     Other
# 2          Ashe  Western North Carolina  2024.0                     Other
# 3         36.5"              Projection     NaN                       NaN
# 4          Ashe  Western North Carolina  2024.0                     White
# ..          ...                     ...     ...                       ...
# 624  Projection                    2024     NaN                       NaN
# 625         Lee  Central North Carolina  2024.0                     White
# 626     Halifax  Eastern North Carolina  2024.0                     Other
# 627  Projection                    2024     NaN                       NaN
# 628  Montgomery  Central North Carolina  2024.0  Asian & Pacific Islander
#
#      Age 65 Plus    Total
# 0         3174.0  10930.0
# 1           73.0    689.0
# 2          245.0   1211.0
# 3            NaN      NaN
# 4         7497.0  25589.0
# ..           ...      ...
# 624          NaN      NaN
# 625      10025.0  51269.0
# 626        110.0   1557.0
# 627          NaN      NaN
# 628         45.0    487.0
#
# [629 rows x 6 columns]

# %%
#region_grouped_24=region_grouped_24[region_grouped_24['County'].isin(NC_IRF_Counties_List)]
#region_grouped_24

# %%
region_grouped_25=race_age_groups_25[['County','Region','Year','Race','Age 65 Plus', 'Total']]
region_grouped_25
# Out:
#         County                  Region    Year                      Race  \
# 0    Alexander  Western North Carolina  2025.0  Asian & Pacific Islander
# 1     Alamance  Central North Carolina  2025.0                     Other
# 2        Burke  Western North Carolina  2025.0                     Black
# 3          NaN                     NaN     NaN                       NaN
# 4         35."              Projection     NaN                       NaN
# ..         ...                     ...     ...                       ...
# 824       Pitt  Eastern North Carolina  2025.0                     Black
# 825        NaN                     NaN     NaN                       NaN
# 826     35.50"              Projection     NaN                       NaN
# 827       Wake  Central North Carolina  2025.0  Asian & Pacific Islander
# 828      Rowan  Central North Carolina  2025.0                     Black
#
#      Age 65 Plus     Total
# 0           35.0     438.0
# 1          220.0    8688.0
# 2          953.0    5184.0
# 3            NaN       NaN
# 4            NaN       NaN
# ..           ...       ...
# 824       8576.0   65899.0
# 825          NaN       NaN
# 826          NaN       NaN
# 827      12371.0  126357.0
# 828       3659.0   25182.0
#
# [829 rows x 6 columns]

# %%
#region_grouped_25=region_grouped_25[region_grouped_25['County'].isin(NC_IRF_Counties_List)]
#region_grouped_25

# %%
dfs=[region_grouped_23, region_grouped_24, region_grouped_25]

regions_grouped_merged = dfs[0]

for i in range(1, len(dfs)):
    regions_grouped_merged= pd.merge(regions_grouped_merged, dfs[i], on = 'County', how ='inner')


regions_grouped_merged
# Out:
#           County                Region_x  Year_x Race_x  Age 65 Plus_x  \
# 0      Brunswick  Eastern North Carolina  2023.0  Other         1684.0
# 1      Brunswick  Eastern North Carolina  2023.0  Other         1684.0
# 2      Brunswick  Eastern North Carolina  2023.0  Other         1684.0
# 3      Brunswick  Eastern North Carolina  2023.0  Other         1684.0
# 4      Brunswick  Eastern North Carolina  2023.0  Other         1684.0
# ...          ...                     ...     ...    ...            ...
# 26581      Surry  Western North Carolina  2023.0  Black          530.0
# 26582      Surry  Western North Carolina  2023.0  Black          530.0
# 26583      Surry  Western North Carolina  2023.0  Black          530.0
# 26584      Surry  Western North Carolina  2023.0  Black          530.0
# 26585      Surry  Western North Carolina  2023.0  Black          530.0
#
#        Total_x                Region_y  Year_y Race_y  Age 65 Plus_y  Total_y  \
# 0       5725.0  Eastern North Carolina  2024.0  Other         1966.0   6261.0
# 1       5725.0  Eastern North Carolina  2024.0  Other         1966.0   6261.0
# 2       5725.0  Eastern North Carolina  2024.0  Other         1966.0   6261.0
# 3       5725.0  Eastern North Carolina  2024.0  Other         1966.0   6261.0
# 4       5725.0  Eastern North Carolina  2024.0  Other         1966.0   6261.0
# ...        ...                     ...     ...    ...            ...      ...
# 26581   2867.0  Western North Carolina  2024.0  Black          546.0   2861.0
# 26582   2867.0  Western North Carolina  2024.0  Black          546.0   2861.0
# 26583   2867.0  Western North Carolina  2024.0  Black          546.0   2861.0
# 26584   2867.0  Western North Carolina  2024.0  Black          546.0   2861.0
# 26585   2867.0  Western North Carolina  2024.0  Black          546.0   2861.0
#
#                        Region    Year                             Race  \
# 0      Eastern North Carolina  2025.0         Asian & Pacific Islander
# 1      Eastern North Carolina  2025.0                            Black
# 2      Eastern North Carolina  2025.0                            White
# 3      Eastern North Carolina  2025.0  American Indian / Alaska Native
# 4      Eastern North Carolina  2025.0                            Other
# ...                       ...     ...                              ...
# 26581  Western North Carolina  2025.0                            Black
# 26582  Western North Carolina  2025.0         Asian & Pacific Islander
# 26583  Western North Carolina  2025.0                            White
# 26584  Western North Carolina  2025.0                            Other
# 26585  Western North Carolina  2025.0  American Indian / Alaska Native
#
#        Age 65 Plus     Total
# 0            547.0    1471.0
# 1           3789.0   13716.0
# 2          64842.0  151581.0
# 3            502.0    1482.0
# 4           2262.0    6797.0
# ...            ...       ...
# 26581        562.0    2856.0
# 26582         58.0     506.0
# 26583      14391.0   65078.0
# 26584        310.0    2568.0
# 26585        178.0     766.0
#
# [26586 rows x 16 columns]

# %%
regions_grouped_merged=regions_grouped_merged.rename(columns={'Age 65 Plus_x':'Age 65 Plus 2023', 'Age 65 Plus_y':'Age 65 Plus 2024','Age 65 Plus':'Age 65 Plus 2025'})
regions_grouped_merged
# Out:
#           County                Region_x  Year_x Race_x  Age 65 Plus 2023  \
# 0      Brunswick  Eastern North Carolina  2023.0  Other            1684.0
# 1      Brunswick  Eastern North Carolina  2023.0  Other            1684.0
# 2      Brunswick  Eastern North Carolina  2023.0  Other            1684.0
# 3      Brunswick  Eastern North Carolina  2023.0  Other            1684.0
# 4      Brunswick  Eastern North Carolina  2023.0  Other            1684.0
# ...          ...                     ...     ...    ...               ...
# 26581      Surry  Western North Carolina  2023.0  Black             530.0
# 26582      Surry  Western North Carolina  2023.0  Black             530.0
# 26583      Surry  Western North Carolina  2023.0  Black             530.0
# 26584      Surry  Western North Carolina  2023.0  Black             530.0
# 26585      Surry  Western North Carolina  2023.0  Black             530.0
#
#        Total_x                Region_y  Year_y Race_y  Age 65 Plus 2024  \
# 0       5725.0  Eastern North Carolina  2024.0  Other            1966.0
# 1       5725.0  Eastern North Carolina  2024.0  Other            1966.0
# 2       5725.0  Eastern North Carolina  2024.0  Other            1966.0
# 3       5725.0  Eastern North Carolina  2024.0  Other            1966.0
# 4       5725.0  Eastern North Carolina  2024.0  Other            1966.0
# ...        ...                     ...     ...    ...               ...
# 26581   2867.0  Western North Carolina  2024.0  Black             546.0
# 26582   2867.0  Western North Carolina  2024.0  Black             546.0
# 26583   2867.0  Western North Carolina  2024.0  Black             546.0
# 26584   2867.0  Western North Carolina  2024.0  Black             546.0
# 26585   2867.0  Western North Carolina  2024.0  Black             546.0
#
#        Total_y                  Region    Year  \
# 0       6261.0  Eastern North Carolina  2025.0
# 1       6261.0  Eastern North Carolina  2025.0
# 2       6261.0  Eastern North Carolina  2025.0
# 3       6261.0  Eastern North Carolina  2025.0
# 4       6261.0  Eastern North Carolina  2025.0
# ...        ...                     ...     ...
# 26581   2861.0  Western North Carolina  2025.0
# 26582   2861.0  Western North Carolina  2025.0
# 26583   2861.0  Western North Carolina  2025.0
# 26584   2861.0  Western North Carolina  2025.0
# 26585   2861.0  Western North Carolina  2025.0
#
#                                   Race  Age 65 Plus 2025     Total
# 0             Asian & Pacific Islander             547.0    1471.0
# 1                                Black            3789.0   13716.0
# 2                                White           64842.0  151581.0
# 3      American Indian / Alaska Native             502.0    1482.0
# 4                                Other            2262.0    6797.0
# ...                                ...               ...       ...
# 26581                            Black             562.0    2856.0
# 26582         Asian & Pacific Islander              58.0     506.0
# 26583                            White           14391.0   65078.0
# 26584                            Other             310.0    2568.0
# 26585  American Indian / Alaska Native             178.0     766.0
#
# [26586 rows x 16 columns]

# %%
regions_grouped_merged= regions_grouped_merged[['County','Region', 'Age 65 Plus 2023','Age 65 Plus 2024','Age 65 Plus 2025']]
regions_grouped_merged
# Out:
#           County                  Region  Age 65 Plus 2023  Age 65 Plus 2024  \
# 0      Brunswick  Eastern North Carolina            1684.0            1966.0
# 1      Brunswick  Eastern North Carolina            1684.0            1966.0
# 2      Brunswick  Eastern North Carolina            1684.0            1966.0
# 3      Brunswick  Eastern North Carolina            1684.0            1966.0
# 4      Brunswick  Eastern North Carolina            1684.0            1966.0
# ...          ...                     ...               ...               ...
# 26581      Surry  Western North Carolina             530.0             546.0
# 26582      Surry  Western North Carolina             530.0             546.0
# 26583      Surry  Western North Carolina             530.0             546.0
# 26584      Surry  Western North Carolina             530.0             546.0
# 26585      Surry  Western North Carolina             530.0             546.0
#
#        Age 65 Plus 2025
# 0                 547.0
# 1                3789.0
# 2               64842.0
# 3                 502.0
# 4                2262.0
# ...                 ...
# 26581             562.0
# 26582              58.0
# 26583           14391.0
# 26584             310.0
# 26585             178.0
#
# [26586 rows x 5 columns]

# %%
regions_grouped_merged_two= regions_grouped_merged.groupby('Region').agg({'Age 65 Plus 2023':'sum',
                                                                          'Age 65 Plus 2024':'sum',
                                                                          'Age 65 Plus 2025':'sum'})
regions_grouped_merged_two
# Out:
#                         Age 65 Plus 2023  Age 65 Plus 2024  Age 65 Plus 2025
# Region
# Central North Carolina        22238064.0        23070716.0        23902441.0
# Eastern North Carolina        12629311.0        13055185.0        13465703.0
# Projection                           0.0               0.0               0.0
# Western North Carolina        10346476.0        10551325.0        10746841.0

# %%
regions_grouped_merged_two['Pct growth 65 plus']= (regions_grouped_merged_two['Age 65 Plus 2025']-regions_grouped_merged_two['Age 65 Plus 2023'])/(regions_grouped_merged_two['Age 65 Plus 2023']) * 100

# %%
regions_grouped_merged_two=regions_grouped_merged_two.reset_index()
regions_grouped_merged_two
# Out:
#                    Region  Age 65 Plus 2023  Age 65 Plus 2024  \
# 0  Central North Carolina        22238064.0        23070716.0
# 1  Eastern North Carolina        12629311.0        13055185.0
# 2              Projection               0.0               0.0
# 3  Western North Carolina        10346476.0        10551325.0
#
#    Age 65 Plus 2025  Pct growth 65 plus
# 0        23902441.0            7.484361
# 1        13465703.0            6.622626
# 2               0.0                 NaN
# 3        10746841.0            3.869578

# %%
regions_grouped_merged_two=regions_grouped_merged_two.drop(2)

# %%
regions_grouped_merged_two
# Out:
#                    Region  Age 65 Plus 2023  Age 65 Plus 2024  \
# 0  Central North Carolina        22238064.0        23070716.0
# 1  Eastern North Carolina        12629311.0        13055185.0
# 3  Western North Carolina        10346476.0        10551325.0
#
#    Age 65 Plus 2025  Pct growth 65 plus
# 0        23902441.0            7.484361
# 1        13465703.0            6.622626
# 3        10746841.0            3.869578

# %%
regions_grouped_merged_two.to_csv('regions_grouped_merged_two.csv', index=False)

# %% [markdown]
# Looking at where the IRFs are by NC region:

# %%
Inpatient_Rehabilitation_Facility-General_Information_Jun2025

# %%
Provider_data_25=pd.read_csv('../data/Inpatient_Rehabilitation_Facility_Provider_Data_Jun2025.csv')
Provider_data_25
# Out:
#       CMS Certification Number (CCN)  \
# 0                              13025
# 1                              13025
# 2                              13025
# 3                              13025
# 4                              13025
# ...                              ...
# 83295                         743031
# 83296                         743031
# 83297                         743031
# 83298                         743031
# 83299                         743031
#
#                                            Provider Name  \
# 0      ENCOMPASS HEALTH LAKESHORE REHABILITATION HOSP...
# 1      ENCOMPASS HEALTH LAKESHORE REHABILITATION HOSP...
# 2      ENCOMPASS HEALTH LAKESHORE REHABILITATION HOSP...
# 3      ENCOMPASS HEALTH LAKESHORE REHABILITATION HOSP...
# 4      ENCOMPASS HEALTH LAKESHORE REHABILITATION HOSP...
# ...                                                  ...
# 83295             HORIZON MEDICAL CENTER OF MCKINNEY LLC
# 83296             HORIZON MEDICAL CENTER OF MCKINNEY LLC
# 83297             HORIZON MEDICAL CENTER OF MCKINNEY LLC
# 83298             HORIZON MEDICAL CENTER OF MCKINNEY LLC
# 83299             HORIZON MEDICAL CENTER OF MCKINNEY LLC
#
#                 Address Line 1 Address Line 2   City/Town State  ZIP Code  \
# 0          3800 RIDGEWAY DRIVE              -  BIRMINGHAM    AL     35209
# 1          3800 RIDGEWAY DRIVE              -  BIRMINGHAM    AL     35209
# 2          3800 RIDGEWAY DRIVE              -  BIRMINGHAM    AL     35209
# 3          3800 RIDGEWAY DRIVE              -  BIRMINGHAM    AL     35209
# 4          3800 RIDGEWAY DRIVE              -  BIRMINGHAM    AL     35209
# ...                        ...            ...         ...   ...       ...
# 83295  6601 W UNIVERSITY DRIVE              -   MC KINNEY    TX     75071
# 83296  6601 W UNIVERSITY DRIVE              -   MC KINNEY    TX     75071
# 83297  6601 W UNIVERSITY DRIVE              -   MC KINNEY    TX     75071
# 83298  6601 W UNIVERSITY DRIVE              -   MC KINNEY    TX     75071
# 83299  6601 W UNIVERSITY DRIVE              -   MC KINNEY    TX     75071
#
#       County/Parish Telephone Number  CMS Region          Measure Code  \
# 0         Jefferson   (205) 868-2000           4     I_006_01_CI_LOWER
# 1         Jefferson   (205) 868-2000           4     I_006_01_CI_UPPER
# 2         Jefferson   (205) 868-2000           4    I_006_01_COMP_PERF
# 3         Jefferson   (205) 868-2000           4    I_006_01_DOPC_DAYS
# 4         Jefferson   (205) 868-2000           4    I_006_01_ELIGCASES
# ...             ...              ...         ...                   ...
# 83295        Collin   (469) 907-1355           6    I_025_02_NUMERATOR
# 83296        Collin   (469) 907-1355           6     I_025_02_OBS_RATE
# 83297        Collin   (469) 907-1355           6  I_026_01_DENOMINATOR
# 83298        Collin   (469) 907-1355           6    I_026_01_NUMERATOR
# 83299        Collin   (469) 907-1355           6     I_026_01_OBS_RATE
#
#                                           Score Footnote Start Date  \
# 0                                         0.821        -   7/1/2023
# 1                                         4.213        -   7/1/2023
# 2      No Different than the National Benchmark        -   7/1/2023
# 3                                         2,743        -   7/1/2023
# 4                                         2.962        -   7/1/2023
# ...                                         ...      ...        ...
# 83295                             Not Available        2  10/1/2023
# 83296                             Not Available        2  10/1/2023
# 83297                             Not Available        2  10/1/2023
# 83298                             Not Available        2  10/1/2023
# 83299                             Not Available        2  10/1/2023
#
#         End Date Measure Date Range
# 0      6/30/2024                  -
# 1      6/30/2024                  -
# 2      6/30/2024                  -
# 3      6/30/2024                  -
# 4      6/30/2024                  -
# ...          ...                ...
# 83295  9/30/2024                  -
# 83296  9/30/2024                  -
# 83297  9/30/2024                  -
# 83298  9/30/2024                  -
# 83299  9/30/2024                  -
#
# [83300 rows x 16 columns]

# %%
NC_Provider_data_25=Provider_data_25.loc[Provider_data_25['State']=='NC']
NC_Provider_data_25
# Out:
#       CMS Certification Number (CCN)                         Provider Name  \
# 48552                         343025  CAREPARTNERS REHABILITATION HOSPITAL
# 48553                         343025  CAREPARTNERS REHABILITATION HOSPITAL
# 48554                         343025  CAREPARTNERS REHABILITATION HOSPITAL
# 48555                         343025  CAREPARTNERS REHABILITATION HOSPITAL
# 48556                         343025  CAREPARTNERS REHABILITATION HOSPITAL
# ...                              ...                                   ...
# 50315                         34T155              DURHAM REGIONAL HOSPITAL
# 50316                         34T155              DURHAM REGIONAL HOSPITAL
# 50317                         34T155              DURHAM REGIONAL HOSPITAL
# 50318                         34T155              DURHAM REGIONAL HOSPITAL
# 50319                         34T155              DURHAM REGIONAL HOSPITAL
#
#             Address Line 1 Address Line 2  City/Town State  ZIP Code  \
# 48552  68 SWEETEN CREEK RD              -  ASHEVILLE    NC     28813
# 48553  68 SWEETEN CREEK RD              -  ASHEVILLE    NC     28813
# 48554  68 SWEETEN CREEK RD              -  ASHEVILLE    NC     28813
# 48555  68 SWEETEN CREEK RD              -  ASHEVILLE    NC     28813
# 48556  68 SWEETEN CREEK RD              -  ASHEVILLE    NC     28813
# ...                    ...            ...        ...   ...       ...
# 50315  3643 N ROXBORO ROAD         BOX 52     DURHAM    NC     27704
# 50316  3643 N ROXBORO ROAD         BOX 52     DURHAM    NC     27704
# 50317  3643 N ROXBORO ROAD         BOX 52     DURHAM    NC     27704
# 50318  3643 N ROXBORO ROAD         BOX 52     DURHAM    NC     27704
# 50319  3643 N ROXBORO ROAD         BOX 52     DURHAM    NC     27704
#
#       County/Parish Telephone Number  CMS Region          Measure Code  \
# 48552      Buncombe   (828) 274-2400           4     I_006_01_CI_LOWER
# 48553      Buncombe   (828) 274-2400           4     I_006_01_CI_UPPER
# 48554      Buncombe   (828) 274-2400           4    I_006_01_COMP_PERF
# 48555      Buncombe   (828) 274-2400           4    I_006_01_DOPC_DAYS
# 48556      Buncombe   (828) 274-2400           4    I_006_01_ELIGCASES
# ...             ...              ...         ...                   ...
# 50315        Durham   (919) 470-7226           4    I_025_02_NUMERATOR
# 50316        Durham   (919) 470-7226           4     I_025_02_OBS_RATE
# 50317        Durham   (919) 470-7226           4  I_026_01_DENOMINATOR
# 50318        Durham   (919) 470-7226           4    I_026_01_NUMERATOR
# 50319        Durham   (919) 470-7226           4     I_026_01_OBS_RATE
#
#                                           Score Footnote Start Date  \
# 48552                                     0.381        -   7/1/2023
# 48553                                     4.078        -   7/1/2023
# 48554  No Different than the National Benchmark        -   7/1/2023
# 48555                                       895        -   7/1/2023
# 48556                                     2.002        -   7/1/2023
# ...                                         ...      ...        ...
# 50315                                       139        -  10/1/2023
# 50316                                       100        -  10/1/2023
# 50317                                       297        -  10/1/2023
# 50318                                        63        -  10/1/2023
# 50319                                     21.21        -  10/1/2023
#
#         End Date Measure Date Range
# 48552  6/30/2024                  -
# 48553  6/30/2024                  -
# 48554  6/30/2024                  -
# 48555  6/30/2024                  -
# 48556  6/30/2024                  -
# ...          ...                ...
# 50315  9/30/2024                  -
# 50316  9/30/2024                  -
# 50317  9/30/2024                  -
# 50318  9/30/2024                  -
# 50319  9/30/2024                  -
#
# [1768 rows x 16 columns]

# %%
NC_Provider_data_25['County/Parish'].nunique()
# Out:
# 19

# %%
NC_Provider_data_25['Provider Name'].nunique()
# Out:
# 26

# %%
unique_IRFs_per_county = NC_Provider_data_25.groupby('County/Parish')['Provider Name'].nunique().to_frame().reset_index()
unique_IRFs_per_county
# Out:
#    County/Parish  Provider Name
# 0       Buncombe              1
# 1        Catawba              2
# 2         Craven              1
# 3     Cumberland              1
# 4         Durham              1
# 5        Forsyth              3
# 6       Guilford              2
# 7         Lenoir              1
# 8    Mecklenburg              4
# 9          Moore              1
# 10          Nash              1
# 11   New Hanover              1
# 12        Orange              1
# 13          Pitt              1
# 14         Rowan              1
# 15      Scotland              1
# 16         Surry              1
# 17         Vance              1
# 18          Wake              1

# %%
unique_IRFs_per_county=unique_IRFs_per_county.rename(columns={'Provider Name':'Number of IRFs'})
unique_IRFs_per_county
# Out:
#    County/Parish  Number of IRFs
# 0       Buncombe               1
# 1        Catawba               2
# 2         Craven               1
# 3     Cumberland               1
# 4         Durham               1
# 5        Forsyth               3
# 6       Guilford               2
# 7         Lenoir               1
# 8    Mecklenburg               4
# 9          Moore               1
# 10          Nash               1
# 11   New Hanover               1
# 12        Orange               1
# 13          Pitt               1
# 14         Rowan               1
# 15      Scotland               1
# 16         Surry               1
# 17         Vance               1
# 18          Wake               1

# %%
NC_IRF_Counties_List=['Buncombe','Catawba','Craven','Cumberland','Durham','Forsyth','Guilford','Lenoir','Mecklenburg','Moore','Nash','New_Hanover','Orange','Pitt','Rowan','Vance','Wake']

# %%
unique_IRFs_per_county=unique_IRFs_per_county[unique_IRFs_per_county['County/Parish'].isin(NC_IRF_Counties_List)]

# %%
unique_IRFs_per_county.to_csv('unique_IRFs_per_county.csv', index=False)
